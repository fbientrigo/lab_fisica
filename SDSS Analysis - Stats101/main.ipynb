# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# # SDSS
# Analisis de los datos

# %%
df = pd.read_csv('SDSS_QSO.csv', index_col=0) # dataframe
print(df.shape) #(observaciones, variables)
df.describe()
# Out:
# (77429, 15)
#                   z         u_mag     sig_u_mag         g_mag     sig_g_mag  \
# count  77429.000000  77429.000000  77429.000000  77429.000000  77429.000000
# mean       1.537516     19.819892      0.089472     19.348567      0.026535
# std        0.821791      1.618784      0.207165      1.214477      0.028608
# min        0.078000      0.000000      0.000000      0.000000      0.000000
# 25%        0.955500     19.092000      0.028000     18.855000      0.019000
# 50%        1.482000     19.584000      0.037000     19.305000      0.023000
# 75%        1.930300     20.298000      0.055000     19.946000      0.028000
# max        5.413500     26.794000      9.999000     26.417000      1.499000
#
#               r_mag     sig_r_mag         i_mag     sig_i_mag         z_mag  \
# count  77429.000000  77429.000000  77429.000000  77429.000000  77429.000000
# mean      19.121966      0.022383     18.974350      0.024640     18.884627
# ...

# %% [markdown]
# # Conociendo los datos
# explorando los datos y sus relaciones, columnas con columnas
# ![datos](description.png)

# %% [markdown]
# Es importante leer los datos, pues de acuerdo a

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Objetivo
# ![objetiv](objectives.png)

# %% [markdown]
# ### Analisis exploratorio
# - medidas de tendencia central, variabilidad, histogramas, etc...

# %% [markdown]
# ### Intervalos de confianza para variables en estudio
# - 95% de mis datos o mediciones se encuentran entre este intervalo
# - aplicable para los datos en si, como tambien para estadisticos, osea cual es la confianza de la media y de la varianza
