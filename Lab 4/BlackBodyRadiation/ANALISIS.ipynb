# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
FourVolts = pd.read_excel("4VOLTS_117°.xlsx")
FourVolts["Angulo (grad)"] += 117

# %%
second_FourVolts = pd.read_excel("4VOLTS_117°_2DAMEDICION.xlsx")
second_FourVolts["Angulo (grad)"] += 117

# %%
max(FourVolts["Intensidad relativa (%)"])
# Out:
# 75.9

# %%
plt.plot(FourVolts["Angulo (grad)"], FourVolts["Intensidad relativa (%)"])

# %%
plt.plot(second_FourVolts["Angulo (grad)"], second_FourVolts["Intensidad relativa (%)"])

# %%
FiveVolts = pd.read_excel("5VOLTS_117°.xlsx", decimal=",")
FiveVolts["Angulo (grad)"] += 117

# %%
second_FiveVolts = pd.read_excel("5VOLTS_117°_2DAMEDICION.xlsx", decimal=",")
second_FiveVolts["Angulo (grad)"] += 117

# %%
max(FiveVolts["Intensidad relativa (%)"])
# Out:
# 66.88

# %%
plt.plot(FiveVolts["Angulo (grad)"], FiveVolts["Intensidad relativa (%)"])

# %%
plt.plot(second_FiveVolts["Angulo (grad)"], second_FiveVolts["Intensidad relativa (%)"])

# %%
SixVoltsdf = pd.read_excel("6.5VOLTS_115°.xlsx", decimal=",")
SixVoltsdf["Angulo (grad)"] += 115

# %%
second_SixVoltsdf = pd.read_excel("6.5VOLTS_115°_2DAMEDICION.xlsx", decimal=",")
second_SixVoltsdf["Angulo (grad)"] += 115

# %%
max(SixVoltsdf["Intensidad relativa (%)"])
# Out:
# 91.88

# %%
plt.plot(SixVoltsdf["Angulo (grad)"], SixVoltsdf["Intensidad relativa (%)"])

# %%
plt.plot(second_SixVoltsdf["Angulo (grad)"], second_SixVoltsdf["Intensidad relativa (%)"])
