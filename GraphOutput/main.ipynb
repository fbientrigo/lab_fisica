# %% [markdown]
# ### Grid
# - crear estrucutras con lineas y sin lineas,
# manejar los intervalos y los ticks
#
#
# - existe una lista de opciones
# - entre ellas se seleccionan mediante switchs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Instrucciones iniciales
y_lim = (-4,4)
x_lim = (0,10)

# %%
# plots vacios
plt.xlim(y_lim[0], y_lim[1])
plt.ylim(x_lim[0], x_lim[1])
plt.show()

# %%
grid = True

plt.xlim(-4, 4)
plt.ylim(0, 10)

if grid :
    plt.grid(color='b', linestyle='--', linewidth=0.5)

plt.show()

# %%
~False
# Out:
# -1

# %%
# config phase
grid = True
view_numbers = {'x':True, 'y':False}


# ----------- plot base structure -------------------

plt.xlim(-4, 4)
plt.ylim(0, 10)

# tamaño de figura

# desactivar ticks
if not view_numbers['x']:
    print('hide x ticks')
    plt.xticks([])

if not view_numbers['y']:
    print('hide y ticks')
    plt.yticks([])


# ----------- grid structure (inside) ---------------
# crear un grid
if grid :
    plt.grid(color='b', linestyle='--', linewidth=0.5)



plt.show()
# Out:
# hide y ticks

# %%
# Out:
# ([], [])

# %%
def grids():
